# %% [markdown]
# # Practice using OpenStreetMap
# ## How I created gas_stations.csv
#
# Create a working, clean dataframe of all gas stations in CA. Columns:
# - Name
# - Latitude
# - Longitude
#
# Columns to add:
# - Heat Category

# %%
import requests
import pandas as pd

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
    [out:json];
    area[name = "California"]->.search;
    node[amenity='fuel'](area.search);
    out count;
"""

response = requests.get(overpass_url, params={'data': overpass_query})
response.json()
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.56.6 474850e8',
#  'osm3s': {'timestamp_osm_base': '2020-10-27T19:06:03Z',
#   'timestamp_areas_base': '2020-10-27T18:38:03Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'count',
#    'id': 0,
#    'tags': {'nodes': '2927',
#     'ways': '0',
#     'relations': '0',
#     'areas': '0',
#     'total': '2927'}}]}

# %% [markdown]
# ### There are a total of 2,927 gas stations in CA

# %%
overpass_url = "http://overpass-api.de/api/interpreter"
overpass_query = """
    [out:json];
    area[name = "California"]->.search;
    node[amenity='fuel'](area.search);
    out;
"""
# specify a bounding box by (south, west, north, east) in latitude and longitude
response = requests.get(overpass_url, params={'data': overpass_query})
response.json()
# Out:
# {'version': 0.6,
#  'generator': 'Overpass API 0.7.56.6 474850e8',
#  'osm3s': {'timestamp_osm_base': '2020-10-27T19:11:02Z',
#   'timestamp_areas_base': '2020-10-27T18:38:03Z',
#   'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.'},
#  'elements': [{'type': 'node',
#    'id': 97044219,
#    'lat': 34.0573651,
#    'lon': -117.1907772,
#    'tags': {'addr:housenumber': '765',
#     'addr:street': 'W Redlands Blvd',
#     'amenity': 'fuel',
#     'description': 'Average fuel prices, best prices on fountain drinks on area. Friendly staff',
#     'name': 'Circle K & Minimart',
#     'opening_hours': '24/7',
#     'operator': 'Circle K'}},
#   {'type': 'node',
#    'id': 98659556,
#    'lat': 34.0485747,
#    'lon': -117.2256087,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.5'}},
#   {'type': 'node',
#    'id': 140103093,
#    'lat': 34.0413876,
#    'lon': -117.1562993,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.5d'}},
#   {'type': 'node',
#    'id': 174130096,
#    'lat': 37.7684682,
#    'lon': -122.420268,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'capacity': '8',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 189845764,
#    'lat': 37.381165,
#    'lon': -122.0701271,
#    'tags': {'amenity': 'fuel', 'created_by': 'JOSM', 'name': 'Valley Oil'}},
#   {'type': 'node',
#    'id': 192554739,
#    'lat': 34.1032728,
#    'lon': -118.2372374,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 193206617,
#    'lat': 37.4060647,
#    'lon': -122.078426,
#    'tags': {'amenity': 'fuel', 'name': 'Arco'}},
#   {'type': 'node',
#    'id': 194986644,
#    'lat': 37.6774981,
#    'lon': -121.7879328,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 194986650,
#    'lat': 37.6777037,
#    'lon': -121.7868756,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 212427452,
#    'lat': 37.8373034,
#    'lon': -122.2503714,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'description': 'Unicol 76',
#     'name': '76'}},
#   {'type': 'node',
#    'id': 212429546,
#    'lat': 37.8407536,
#    'lon': -122.2372221,
#    'tags': {'amenity': 'fuel',
#     'description': 'independent, w/service',
#     'name': 'Car Service'}},
#   {'type': 'node',
#    'id': 212467654,
#    'lat': 37.8404305,
#    'lon': -122.2615441,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.7',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 212468461,
#    'lat': 37.8394465,
#    'lon': -122.2700151,
#    'tags': {'amenity': 'fuel', 'name': 'Mobil'}},
#   {'type': 'node',
#    'id': 212469149,
#    'lat': 37.8400252,
#    'lon': -122.2701261,
#    'tags': {'amenity': 'fuel', 'name': 'Fuel 24:7'}},
#   {'type': 'node',
#    'id': 236584376,
#    'lat': 37.7755014,
#    'lon': -122.2334503,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 246739177,
#    'lat': 37.8255858,
#    'lon': -122.2097519,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.7',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 247365642,
#    'lat': 37.8579312,
#    'lon': -122.2441212,
#    'tags': {'amenity': 'fuel', 'brand': 'Chevron', 'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 247366150,
#    'lat': 37.84382,
#    'lon': -122.2467567,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.7a'}},
#   {'type': 'node',
#    'id': 250033556,
#    'lat': 37.581745,
#    'lon': -122.35037,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.8a',
#     'name': 'Valero'}},
#   {'type': 'node',
#    'id': 250291068,
#    'lat': 37.5803881,
#    'lon': -122.3341399,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 250632302,
#    'lat': 37.5872485,
#    'lon': -122.3634177,
#    'tags': {'amenity': 'fuel', 'operator': 'Chevron'}},
#   {'type': 'node',
#    'id': 250632322,
#    'lat': 37.5876457,
#    'lon': -122.3623912,
#    'tags': {'amenity': 'fuel', 'note': 'car_wash', 'operator': 'Chevron'}},
#   {'type': 'node',
#    'id': 250632459,
#    'lat': 37.578398,
#    'lon': -122.3371847,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.10e',
#     'operator': 'Shell'}},
#   {'type': 'node',
#    'id': 250632670,
#    'lat': 37.5887203,
#    'lon': -122.3627774,
#    'tags': {'amenity': 'fuel', 'name': 'Valero', 'note': 'car_wash'}},
#   {'type': 'node',
#    'id': 260700308,
#    'lat': 37.2210474,
#    'lon': -121.8623645,
#    'tags': {'amenity': 'fuel', 'created_by': 'JOSM', 'name': '76'}},
#   {'type': 'node',
#    'id': 266578650,
#    'lat': 33.7165414,
#    'lon': -117.954905,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 266899751,
#    'lat': 37.8385166,
#    'lon': -120.230955,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.9a',
#     'source': 'survey'}},
#   {'type': 'node',
#    'id': 266913703,
#    'lat': 37.3731217,
#    'lon': -122.087399,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 273539535,
#    'lat': 32.8670766,
#    'lon': -117.2158525,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 274190443,
#    'lat': 32.8548259,
#    'lon': -117.2041575,
#    'tags': {'amenity': 'fuel', 'name': 'World'}},
#   {'type': 'node',
#    'id': 274191047,
#    'lat': 32.8543944,
#    'lon': -117.204072,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 274191409,
#    'lat': 32.8542675,
#    'lon': -117.2049467,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Mobil',
#     'brand:wikidata': 'Q3088656',
#     'brand:wikipedia': 'en:Mobil',
#     'name': 'Mobil'}},
#   {'type': 'node',
#    'id': 274193680,
#    'lat': 32.8227832,
#    'lon': -117.1843763,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.9c'}},
#   {'type': 'node',
#    'id': 274363014,
#    'lat': 32.8342381,
#    'lon': -117.1950836,
#    'tags': {'amenity': 'fuel', 'name': 'Clairemont Auto Care'}},
#   {'type': 'node',
#    'id': 274363141,
#    'lat': 32.8342381,
#    'lon': -117.1944828,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.9c'}},
#   {'type': 'node',
#    'id': 274363836,
#    'lat': 32.8348112,
#    'lon': -117.1950936,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 274487556,
#    'lat': 38.5510626,
#    'lon': -121.6964249,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 274830997,
#    'lat': 34.0909625,
#    'lon': -118.0903715,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.9c',
#     'name': 'Chevron Mission Car Wash'}},
#   {'type': 'node',
#    'id': 276559888,
#    'lat': 37.6003825,
#    'lon': -122.3831517,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 277357320,
#    'lat': 40.0093833,
#    'lon': -123.7905532,
#    'tags': {'amenity': 'fuel', 'name': 'Patriot'}},
#   {'type': 'node',
#    'id': 281561674,
#    'lat': 37.551753,
#    'lon': -122.30565,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 281881093,
#    'lat': 34.0635637,
#    'lon': -117.2255432,
#    'tags': {'amenity': 'fuel', 'name': 'Arco'}},
#   {'type': 'node',
#    'id': 281881139,
#    'lat': 34.0655247,
#    'lon': -117.2264817,
#    'tags': {'amenity': 'fuel', 'name': 'Shell'}},
#   {'type': 'node',
#    'id': 281881155,
#    'lat': 34.0646722,
#    'lon': -117.2092079,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell',
#     'operator': 'Shell'}},
#   {'type': 'node',
#    'id': 286081336,
#    'lat': 37.8684979,
#    'lon': -122.2664016,
#    'tags': {'amenity': 'fuel',
#     'name': 'Touchless Gasoline',
#     'opening_hours': 'closed'}},
#   {'type': 'node',
#    'id': 288372534,
#    'lat': 38.546829,
#    'lon': -121.7593854,
#    'tags': {'addr:city': 'Davis',
#     'addr:housenumber': '705',
#     'addr:postcode': '95616',
#     'addr:street': 'Russell Boulevard',
#     'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 288561875,
#    'lat': 34.0623716,
#    'lon': -117.1808061,
#    'tags': {'amenity': 'fuel',
#     'automated': 'yes',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'fuel:diesel': 'no',
#     'name': 'Chevron',
#     'opening_hours': '24/7',
#     'self_service': 'yes',
#     'source': 'bing_imagery_0.06m_200706;survey;image',
#     'source_ref': 'AM909_DSCW8317',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 290288735,
#    'lat': 37.4792248,
#    'lon': -122.1518909,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron',
#     'operator': 'Chevron'}},
#   {'type': 'node',
#    'id': 290365135,
#    'lat': 39.2662359,
#    'lon': -123.2041124,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10b'}},
#   {'type': 'node',
#    'id': 295083057,
#    'lat': 37.764585,
#    'lon': -122.4243389,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell',
#     'operator': 'Shell'}},
#   {'type': 'node',
#    'id': 297839095,
#    'lat': 33.8798779,
#    'lon': -118.1429756,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10b'}},
#   {'type': 'node',
#    'id': 298559251,
#    'lat': 33.831782,
#    'lon': -118.0875412,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 300940606,
#    'lat': 33.7423831,
#    'lon': -118.099086,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'source': 'usgs_imagery;survey;image',
#     'source_ref': 'AM909_DSCU5026'}},
#   {'type': 'node',
#    'id': 300955848,
#    'lat': 33.7467724,
#    'lon': -118.105936,
#    'tags': {'amenity': 'fuel',
#     'atm': 'yes',
#     'brand': 'ARCO',
#     'fuel:diesel': 'no',
#     'shop': 'smog_check',
#     'source': 'usgs_imagery;survey;image',
#     'source_ref': 'AM909_DSCU1644'}},
#   {'type': 'node',
#    'id': 303219096,
#    'lat': 37.3382722,
#    'lon': -122.009687,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10d'}},
#   {'type': 'node',
#    'id': 304911683,
#    'lat': 33.887245,
#    'lon': -118.105441,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10e'}},
#   {'type': 'node',
#    'id': 304911715,
#    'lat': 33.8890904,
#    'lon': -118.1249503,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10e'}},
#   {'type': 'node',
#    'id': 305533546,
#    'lat': 37.6405002,
#    'lon': -122.4015096,
#    'tags': {'access': 'customers',
#     'amenity': 'fuel',
#     'brand': 'Costco Gasoline',
#     'brand:wikidata': 'Q715583',
#     'brand:wikipedia': 'en:Costco',
#     'membership': 'yes',
#     'name': 'Costco Gasoline',
#     'note': 'Membership required',
#     'operator': 'Costco'}},
#   {'type': 'node',
#    'id': 307507263,
#    'lat': 37.8554553,
#    'lon': -122.2668563,
#    'tags': {'amenity': 'fuel', 'operator': 'Chevron'}},
#   {'type': 'node',
#    'id': 307507588,
#    'lat': 37.8503278,
#    'lon': -122.260754,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 310972979,
#    'lat': 37.7621609,
#    'lon': -122.244179,
#    'tags': {'addr:city': 'Alameda',
#     'addr:housenumber': '1260',
#     'addr:postcode': '94501',
#     'addr:state': 'CA',
#     'addr:street': 'Park Street',
#     'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 310973083,
#    'lat': 37.7665265,
#    'lon': -122.241209,
#    'tags': {'addr:city': 'Alameda',
#     'addr:housenumber': '1541',
#     'addr:postcode': '94501',
#     'addr:street': 'Park Street',
#     'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'name': '76'}},
#   {'type': 'node',
#    'id': 313422835,
#    'lat': 37.3268208,
#    'lon': -121.8752593,
#    'tags': {'amenity': 'fuel', 'name': 'Cal Gas'}},
#   {'type': 'node',
#    'id': 313422931,
#    'lat': 37.3411416,
#    'lon': -121.879584,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 314082906,
#    'lat': 37.3540568,
#    'lon': -122.0887173,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 314447128,
#    'lat': 39.1913805,
#    'lon': -123.2084302,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 314506778,
#    'lat': 39.151165,
#    'lon': -123.1993253,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 314532190,
#    'lat': 37.0210099,
#    'lon': -121.5694177,
#    'tags': {'addr:city': 'Gilroy',
#     'addr:county': 'Santa Clara',
#     'addr:housenumber': '390',
#     'addr:postcode': '95020-3607',
#     'addr:street': 'Leavesley Road',
#     'amenity': 'fuel',
#     'brand': 'Independent',
#     'fuel:HGV_diesel': 'yes',
#     'fuel:diesel': 'yes',
#     'fuel:kerosene_K-1': 'yes',
#     'fuel:octane_87': 'yes',
#     'fuel:octane_89': 'yes',
#     'fuel:octane_91': 'yes',
#     'name': 'Rotten Robbie #31',
#     'opening_hours': '24/7',
#     'phone': '+1 408-842-3630',
#     'source': 'Yahoo',
#     'url': 'http://rottenrobbie.com/'}},
#   {'type': 'node',
#    'id': 315014444,
#    'lat': 33.7158403,
#    'lon': -117.9540019,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 315014445,
#    'lat': 33.7158375,
#    'lon': -117.9549989,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Mobil',
#     'brand:wikidata': 'Q3088656',
#     'brand:wikipedia': 'en:Mobil',
#     'name': 'Mobil'}},
#   {'type': 'node',
#    'id': 315024019,
#    'lat': 37.3524507,
#    'lon': -122.031886,
#    'tags': {'addr:city': 'Sunnyvale',
#     'addr:full': '1296 Sunnyvale-Saratoga Road, Sunnyvale, CA',
#     'addr:housenumber': '1296',
#     'addr:street': 'Sunnyvale-Saratoga Road',
#     'amenity': 'fuel',
#     'brand': '76',
#     'operator': '76'}},
#   {'type': 'node',
#    'id': 315693037,
#    'lat': 37.0008405,
#    'lon': -121.56538,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.10f',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 315986984,
#    'lat': 37.3406041,
#    'lon': -121.8806386,
#    'tags': {'amenity': 'fuel',
#     'brand': '7-Eleven',
#     'brand:wikidata': 'Q259340',
#     'brand:wikipedia': 'en:7-Eleven',
#     'name': '7-Eleven'}},
#   {'type': 'node',
#    'id': 316000860,
#    'lat': 37.3775792,
#    'lon': -122.1177536,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 316566118,
#    'lat': 36.984475,
#    'lon': -121.557907,
#    'tags': {'addr:city': 'Gilroy',
#     'addr:housenumber': '5887',
#     'amenity': 'fuel',
#     'atm': 'yes',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'car_wash': 'no',
#     'name': 'Chevron',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 316567169,
#    'lat': 36.9848483,
#    'lon': -121.5561206,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 317081637,
#    'lat': 37.7798017,
#    'lon': -122.3980556,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.10f',
#     'operator': 'Shell',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 317332990,
#    'lat': 38.8352662,
#    'lon': -121.1694652,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.10f',
#     'name': '76',
#     'source': 'Yahoo'}},
#   {'type': 'node',
#    'id': 317333142,
#    'lat': 38.8359883,
#    'lon': -121.1680404,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.10f',
#     'name': 'Valero',
#     'source': 'Yahoo'}},
#   {'type': 'node',
#    'id': 317481695,
#    'lat': 34.8261727,
#    'lon': -114.5956965,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 317939836,
#    'lat': 37.8852816,
#    'lon': -122.2745283,
#    'tags': {'addr:city': 'Berkeley',
#     'addr:country': 'US',
#     'addr:housenumber': '1201',
#     'addr:state': 'CA',
#     'addr:street': 'The Alameda',
#     'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 318304424,
#    'lat': 37.7181761,
#    'lon': -122.4729103,
#    'tags': {'amenity': 'fuel',
#     'name': 'Chevron',
#     'toilets': 'yes',
#     'toilets:opening_hours': '07:00-22:00'}},
#   {'type': 'node',
#    'id': 318312719,
#    'lat': 37.7177867,
#    'lon': -122.4427831,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 319608630,
#    'lat': 37.0191388,
#    'lon': -121.5749645,
#    'tags': {'amenity': 'fuel', 'name': 'VP'}},
#   {'type': 'node',
#    'id': 320480230,
#    'lat': 36.8491189,
#    'lon': -121.402366,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.10f',
#     'name': "Jesse's"}},
#   {'type': 'node',
#    'id': 321938942,
#    'lat': 37.1248933,
#    'lon': -121.6501727,
#    'tags': {'addr:city': 'Morgan Hill',
#     'addr:country': 'US',
#     'addr:county': 'Santa Clara',
#     'addr:housenumber': '16995',
#     'addr:postcode': '95037-5135',
#     'addr:state': 'CA',
#     'addr:street': 'Monterey Street',
#     'amenity': 'fuel',
#     'brand': 'Independent',
#     'contact:phone': '+1 408-782-7986',
#     'fuel:diesel_2': 'yes',
#     'fuel:octane_87': 'yes',
#     'fuel:octane_89': 'yes',
#     'fuel:octane_91': 'yes',
#     'name': 'Golden Eagle',
#     'operator': 'Golden Eagle Gas LLC'}},
#   {'type': 'node',
#    'id': 322989327,
#    'lat': 39.1594319,
#    'lon': -123.2085626,
#    'tags': {'amenity': 'fuel', 'name': 'Quest Mart'}},
#   {'type': 'node',
#    'id': 323618012,
#    'lat': 38.3783312,
#    'lon': -120.8019829,
#    'tags': {'amenity': 'fuel', 'name': 'Shell'}},
#   {'type': 'node',
#    'id': 326709112,
#    'lat': 37.1306932,
#    'lon': -121.637068,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron',
#     'operator': 'Chevron'}},
#   {'type': 'node',
#    'id': 330362638,
#    'lat': 34.1030456,
#    'lon': -118.073949,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'fuel:diesel': 'yes',
#     'name': 'Chevron',
#     'source': 'usgs_imagery;survey;image',
#     'source_ref': 'AM909_DSCU3583'}},
#   {'type': 'node',
#    'id': 330362675,
#    'lat': 34.1034245,
#    'lon': -118.073091,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Mobil',
#     'brand:wikidata': 'Q3088656',
#     'brand:wikipedia': 'en:Mobil',
#     'fuel:diesel': 'no',
#     'name': 'Mobil',
#     'source': 'usgs_imagery;survey;image',
#     'source_ref': 'AM909_DSCU3584'}},
#   {'type': 'node',
#    'id': 330364040,
#    'lat': 34.1225451,
#    'lon': -118.07328,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'fuel:diesel': 'yes',
#     'fuel:octane_91': 'yes',
#     'name': '76'}},
#   {'type': 'node',
#    'id': 330364612,
#    'lat': 34.1499462,
#    'lon': -118.0729796,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 331071998,
#    'lat': 37.083717,
#    'lon': -121.6099513,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f', 'name': '76'}},
#   {'type': 'node',
#    'id': 331080859,
#    'lat': 37.100976,
#    'lon': -121.6241447,
#    'tags': {'amenity': 'fuel', 'name': '76 Gas Station'}},
#   {'type': 'node',
#    'id': 331093454,
#    'lat': 37.1445217,
#    'lon': -121.6651215,
#    'tags': {'amenity': 'fuel',
#     'fuel:octane_87': 'yes',
#     'fuel:octane_91': 'yes',
#     'operator': 'Arco'}},
#   {'type': 'node',
#    'id': 331367849,
#    'lat': 37.5886437,
#    'lon': -122.3606694,
#    'tags': {'amenity': 'fuel', 'name': '76'}},
#   {'type': 'node',
#    'id': 332095949,
#    'lat': 37.9921072,
#    'lon': -122.3002441,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Valero',
#     'brand:wikidata': 'Q1283291',
#     'brand:wikipedia': 'en:Valero Energy',
#     'name': 'Valero'}},
#   {'type': 'node',
#    'id': 332096231,
#    'lat': 37.9884083,
#    'lon': -122.3115928,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 332097735,
#    'lat': 37.9791807,
#    'lon': -122.2956627,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 332098049,
#    'lat': 37.9605327,
#    'lon': -122.2833288,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.10f',
#     'name': 'Golden Gate Petroleum'}},
#   {'type': 'node',
#    'id': 332099681,
#    'lat': 37.9644305,
#    'lon': -122.3178499,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 332112359,
#    'lat': 37.0132212,
#    'lon': -121.5819534,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 332132401,
#    'lat': 37.9866117,
#    'lon': -122.317717,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 334396117,
#    'lat': 37.9786311,
#    'lon': -122.3320017,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 334414153,
#    'lat': 37.9630804,
#    'lon': -122.3250443,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 334788949,
#    'lat': 37.976607,
#    'lon': -122.3130014,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 338837210,
#    'lat': 37.5963082,
#    'lon': -122.365114,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 339574653,
#    'lat': 37.4544367,
#    'lon': -122.1295901,
#    'tags': {'amenity': 'fuel',
#     'name': "Ranier's Service Station",
#     'service': 'parts;repair;tyres',
#     'shop': 'car_repair'}},
#   {'type': 'node',
#    'id': 340151574,
#    'lat': 37.566539,
#    'lon': -122.0227705,
#    'tags': {'addr:city': 'Fremont',
#     'addr:country': 'US',
#     'addr:full': '35900 Fremont Boulevard, CA 94536',
#     'addr:housenumber': '35900',
#     'addr:postcode': '94536',
#     'addr:state': 'California',
#     'addr:street': 'Fremont Boulevard',
#     'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'contact:phone': '15107918949',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 340151650,
#    'lat': 37.5681989,
#    'lon': -122.0261522,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'name': '76'}},
#   {'type': 'node',
#    'id': 342844820,
#    'lat': 37.9472716,
#    'lon': -119.1131946,
#    'tags': {'amenity': 'fuel', 'name': 'Mobil'}},
#   {'type': 'node',
#    'id': 343311761,
#    'lat': 37.8911539,
#    'lon': -122.2789461,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'name': '76',
#     'operator': '76'}},
#   {'type': 'node',
#    'id': 343317760,
#    'lat': 37.9021882,
#    'lon': -122.3043584,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'name': '76',
#     'phone': '+1 510 525 6848',
#     'website': 'https://www.76.com/'}},
#   {'type': 'node',
#    'id': 343317820,
#    'lat': 37.9016186,
#    'lon': -122.298693,
#    'tags': {'amenity': 'fuel',
#     'name': 'R&R',
#     'website': 'http://www.randrauto.com/'}},
#   {'type': 'node',
#    'id': 343317826,
#    'lat': 37.9009497,
#    'lon': -122.309519,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'shop': 'convenience',
#     'toilets': 'yes'}},
#   {'type': 'node',
#    'id': 344724678,
#    'lat': 34.1778393,
#    'lon': -118.3182378,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 345491386,
#    'lat': 37.8023325,
#    'lon': -122.2826185,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell',
#     'operator': 'Shell'}},
#   {'type': 'node',
#    'id': 347265864,
#    'lat': 37.8088829,
#    'lon': -122.2754621,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 347719574,
#    'lat': 34.0914214,
#    'lon': -118.0912003,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.10f',
#     'name': 'Mission 76'}},
#   {'type': 'node',
#    'id': 348183427,
#    'lat': 34.3958866,
#    'lon': -118.9173442,
#    'tags': {'amenity': 'fuel', 'name': 'USA Gasoline'}},
#   {'type': 'node',
#    'id': 348183506,
#    'lat': 34.3958016,
#    'lon': -118.9180341,
#    'tags': {'amenity': 'fuel', 'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 348183509,
#    'lat': 34.3973101,
#    'lon': -118.9115281,
#    'tags': {'amenity': 'fuel', 'name': 'Circle K'}},
#   {'type': 'node',
#    'id': 348183510,
#    'lat': 34.3958653,
#    'lon': -118.9229522,
#    'tags': {'amenity': 'fuel', 'name': '7 - Eleven'}},
#   {'type': 'node',
#    'id': 348184786,
#    'lat': 34.395178,
#    'lon': -118.927553,
#    'tags': {'addr:housenumber': '1107',
#     'addr:street': 'West Ventura Street',
#     'amenity': 'fuel',
#     'created_by': 'Potlatch 0.10f',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 354423786,
#    'lat': 38.386672,
#    'lon': -122.7140874,
#    'tags': {'amenity': 'fuel',
#     'atm': 'yes',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 354423977,
#    'lat': 38.3874457,
#    'lon': -122.7154349,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Rotten Robbie',
#     'fuel:lpg': 'yes',
#     'name': 'Rotten Robbie'}},
#   {'type': 'node',
#    'id': 356598953,
#    'lat': 39.291968,
#    'lon': -120.6787786,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'contact:phone': '530-389-8212',
#     'contact:website': 'http://nyackshell.com/',
#     'name': 'Nyack Shell',
#     'operator': 'Nyack Shell',
#     'shop': 'convenience',
#     'wheelchair': 'yes'}},
#   {'type': 'node',
#    'id': 358561623,
#    'lat': 38.9038182,
#    'lon': -121.0759245,
#    'tags': {'amenity': 'fuel', 'name': 'Shell'}},
#   {'type': 'node',
#    'id': 358893271,
#    'lat': 37.7403703,
#    'lon': -122.4236096,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 360146884,
#    'lat': 38.9183697,
#    'lon': -121.0598603,
#    'tags': {'amenity': 'fuel', 'name': 'Shell'}},
#   {'type': 'node',
#    'id': 361134324,
#    'lat': 34.0631935,
#    'lon': -117.1909435,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Valero',
#     'brand:wikidata': 'Q1283291',
#     'brand:wikipedia': 'en:Valero Energy',
#     'name': 'Valero'}},
#   {'type': 'node',
#    'id': 361335031,
#    'lat': 33.8732434,
#    'lon': -118.1168861,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.10f',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 362645159,
#    'lat': 33.6662881,
#    'lon': -117.8820081,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 362651129,
#    'lat': 33.6804508,
#    'lon': -117.9074196,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 362651195,
#    'lat': 33.6798795,
#    'lon': -117.9073767,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 362651298,
#    'lat': 33.6797866,
#    'lon': -117.9081749,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 363122078,
#    'lat': 33.6821681,
#    'lon': -117.8853357,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 363122539,
#    'lat': 33.682687,
#    'lon': -117.8859959,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 363126567,
#    'lat': 33.6798397,
#    'lon': -117.8860224,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 364202812,
#    'lat': 37.4294093,
#    'lon': -122.2506126,
#    'tags': {'amenity': 'fuel',
#     'created_by': 'Potlatch 0.10f',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 364314934,
#    'lat': 33.5268906,
#    'lon': -117.711324,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell',
#     'source': 'yahoo_imagery;survey;image',
#     'source_ref': 'AM909_DSCU9943'}},
#   {'type': 'node',
#    'id': 364314945,
#    'lat': 33.5265253,
#    'lon': -117.712213,
#    'tags': {'amenity': 'fuel',
#     'automated': 'yes',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'car_wash': 'yes',
#     'name': '76',
#     'self_service': 'yes',
#     'shop': 'convenience;car_repair',
#     'source': 'yahoo_imagery;survey;image',
#     'source_ref': 'AM909_DSCU9942'}},
#   {'type': 'node',
#    'id': 365328362,
#    'lat': 32.832383,
#    'lon': -117.152859,
#    'tags': {'amenity': 'fuel',
#     'brand': '7-Eleven',
#     'brand:wikidata': 'Q259340',
#     'brand:wikipedia': 'en:7-Eleven',
#     'name': '7-Eleven',
#     'source': 'SanGIS Business Sites Public Domain (http://www.sangis.org/)'}},
#   {'type': 'node',
#    'id': 369888362,
#    'lat': 34.1032054,
#    'lon': -118.0775016,
#    'tags': {'amenity': 'fuel',
#     'brand': 'USA Gasoline',
#     'brand:wikidata': 'Q17126373',
#     'brand:wikipedia': 'en:USA Gasoline',
#     'name': 'USA Gasoline'}},
#   {'type': 'node',
#    'id': 369888491,
#    'lat': 34.1300433,
#    'lon': -118.072831,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'fuel:diesel': 'no',
#     'name': 'Shell',
#     'payment:credit_cards': 'surcharge',
#     'source': 'usgs_imagery;survey;image',
#     'source_ref': 'AM909_DSCU3615'}},
#   {'type': 'node',
#    'id': 369931525,
#    'lat': 37.3216867,
#    'lon': -122.0682149,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 370376757,
#    'lat': 34.1031321,
#    'lon': -118.0993656,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'fuel:diesel': 'no',
#     'name': '76',
#     'source': 'usgs_imagery;survey;image',
#     'source_ref': 'AM909_DSCV1765'}},
#   {'type': 'node',
#    'id': 371764826,
#    'lat': 34.1499369,
#    'lon': -118.0737443,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'name': '76'}},
#   {'type': 'node',
#    'id': 373430104,
#    'lat': 38.8872665,
#    'lon': -121.0162696,
#    'tags': {'amenity': 'fuel', 'created_by': 'Potlatch 0.10f'}},
#   {'type': 'node',
#    'id': 378565898,
#    'lat': 34.8518589,
#    'lon': -117.083441,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 380318679,
#    'lat': 34.2455629,
#    'lon': -118.4219203,
#    'tags': {'amenity': 'fuel', 'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 380550950,
#    'lat': 35.2672774,
#    'lon': -119.025986,
#    'tags': {'amenity': 'fuel', 'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 382384907,
#    'lat': 37.5844628,
#    'lon': -122.3663721,
#    'tags': {'amenity': 'fuel', 'name': '76'}},
#   {'type': 'node',
#    'id': 383722008,
#    'lat': 33.8325235,
#    'lon': -118.099333,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 384395175,
#    'lat': 37.8730923,
#    'lon': -122.273378,
#    'tags': {'addr:city': 'Berkeley',
#     'addr:housenumber': '1900',
#     'addr:street': 'Martin Luther King Jr Way',
#     'amenity': 'fuel',
#     'name': '#1 Gas',
#     'opening_hours': '24/7'}},
#   {'type': 'node',
#    'id': 387128141,
#    'lat': 37.3781204,
#    'lon': -122.0751723,
#    'tags': {'addr:housenumber': '1220',
#     'addr:street': 'Grant Road',
#     'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 392776783,
#    'lat': 36.8741542,
#    'lon': -121.7597078,
#    'tags': {'amenity': 'fuel', 'name': 'Hilltop'}},
#   {'type': 'node',
#    'id': 392786963,
#    'lat': 36.9843969,
#    'lon': -121.9567864,
#    'tags': {'amenity': 'fuel', 'name': 'Valero'}},
#   {'type': 'node',
#    'id': 392953025,
#    'lat': 36.9825909,
#    'lon': -121.9565025,
#    'tags': {'amenity': 'fuel', 'name': 'Chevron', 'operator': 'Chevron'}},
#   {'type': 'node',
#    'id': 392954596,
#    'lat': 36.9071679,
#    'lon': -121.7538276,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 392954611,
#    'lat': 36.9066738,
#    'lon': -121.753347,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 392955012,
#    'lat': 36.9043403,
#    'lon': -121.7499138,
#    'tags': {'amenity': 'fuel', 'name': 'Quickstop'}},
#   {'type': 'node',
#    'id': 393550862,
#    'lat': 34.0575158,
#    'lon': -117.1807121,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell',
#     'operator': 'Shell'}},
#   {'type': 'node',
#    'id': 393737824,
#    'lat': 37.7815425,
#    'lon': -122.4518447,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'capacity': '8',
#     'name': 'Shell',
#     'operator': 'Shell',
#     'source': 'survey'}},
#   {'type': 'node',
#    'id': 395033749,
#    'lat': 38.5488231,
#    'lon': -121.7341586,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 395034133,
#    'lat': 36.9797568,
#    'lon': -122.0216947,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 395035000,
#    'lat': 36.9812589,
#    'lon': -122.0110947,
#    'tags': {'amenity': 'fuel', 'name': 'Rod & Ros'}},
#   {'type': 'node',
#    'id': 395039757,
#    'lat': 36.9808578,
#    'lon': -121.9651116,
#    'tags': {'amenity': 'fuel', 'name': '76'}},
#   {'type': 'node',
#    'id': 395042391,
#    'lat': 36.9745011,
#    'lon': -121.887701,
#    'tags': {'amenity': 'fuel', 'name': 'Arco'}},
#   {'type': 'node',
#    'id': 401461436,
#    'lat': 36.9722889,
#    'lon': -122.0357725,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'name': '76'}},
#   {'type': 'node',
#    'id': 401461437,
#    'lat': 36.9760263,
#    'lon': -122.0322076,
#    'tags': {'addr:city': 'Santa Cruz',
#     'addr:housenumber': '335',
#     'addr:postcode': '95060',
#     'addr:state': 'CA',
#     'addr:street': 'Mission Street',
#     'amenity': 'fuel',
#     'brand': '76',
#     'name': "76 (Om's Market)"}},
#   {'type': 'node',
#    'id': 401461447,
#    'lat': 36.9636595,
#    'lon': -122.0431888,
#    'tags': {'amenity': 'fuel', 'name': 'Rotten Robbie'}},
#   {'type': 'node',
#    'id': 401461448,
#    'lat': 36.9622061,
#    'lon': -122.045279,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Valero',
#     'brand:wikidata': 'Q1283291',
#     'brand:wikipedia': 'en:Valero Energy',
#     'name': 'Valero'}},
#   {'type': 'node',
#    'id': 401947076,
#    'lat': 37.0566894,
#    'lon': -120.8422758,
#    'tags': {'amenity': 'fuel', 'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 401949907,
#    'lat': 37.0829258,
#    'lon': -120.4775555,
#    'tags': {'amenity': 'fuel', 'name': 'Kwick Serve'}},
#   {'type': 'node',
#    'id': 401976140,
#    'lat': 37.0187478,
#    'lon': -120.1326253,
#    'tags': {'amenity': 'fuel', 'name': 'Pilot'}},
#   {'type': 'node',
#    'id': 402285565,
#    'lat': 36.8084557,
#    'lon': -119.8846331,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 402286377,
#    'lat': 36.8087031,
#    'lon': -119.8634415,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'name': '76'}},
#   {'type': 'node',
#    'id': 402286544,
#    'lat': 36.8079334,
#    'lon': -119.8621969,
#    'tags': {'amenity': 'fuel', 'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 402289144,
#    'lat': 36.9761583,
#    'lon': -120.0744833,
#    'tags': {'amenity': 'fuel', 'brand': 'Shell', 'name': 'Shell Gas Station'}},
#   {'type': 'node',
#    'id': 402295768,
#    'lat': 37.0571945,
#    'lon': -120.8399589,
#    'tags': {'amenity': 'fuel', 'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 402987148,
#    'lat': 38.7362476,
#    'lon': -122.1445583,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 403753275,
#    'lat': 36.9843708,
#    'lon': -122.0234614,
#    'tags': {'amenity': 'fuel', 'name': 'Sav On Gasoline'}},
#   {'type': 'node',
#    'id': 403753276,
#    'lat': 36.9835434,
#    'lon': -122.0231448,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Valero',
#     'brand:wikidata': 'Q1283291',
#     'brand:wikipedia': 'en:Valero Energy',
#     'name': 'Valero'}},
#   {'type': 'node',
#    'id': 403761937,
#    'lat': 36.9812502,
#    'lon': -122.0043858,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Valero',
#     'brand:wikidata': 'Q1283291',
#     'brand:wikipedia': 'en:Valero Energy',
#     'name': 'Valero'}},
#   {'type': 'node',
#    'id': 406559036,
#    'lat': 36.9847207,
#    'lon': -122.0359603,
#    'tags': {'access': 'customers',
#     'amenity': 'fuel',
#     'brand': 'Costco Gasoline',
#     'brand:wikidata': 'Q715583',
#     'brand:wikipedia': 'en:Costco',
#     'membership': 'yes',
#     'name': 'Costco Gasoline',
#     'name:zh': '好市多',
#     'operator': 'Costco'}},
#   {'type': 'node',
#    'id': 409475787,
#    'lat': 37.7792862,
#    'lon': -122.4984557,
#    'tags': {'amenity': 'fuel',
#     'capacity': '6',
#     'name': '76 Gas',
#     'operator': '76'}},
#   {'type': 'node',
#    'id': 409821486,
#    'lat': 36.9646926,
#    'lon': -122.0417144,
#    'tags': {'amenity': 'fuel', 'name': 'APCO Gasoline'}},
#   {'type': 'node',
#    'id': 409821489,
#    'lat': 36.9630144,
#    'lon': -122.0431356,
#    'tags': {'amenity': 'fuel', 'name': 'Gas & Shop'}},
#   {'type': 'node',
#    'id': 411243755,
#    'lat': 38.331753,
#    'lon': -122.7146201,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Valero',
#     'brand:wikidata': 'Q1283291',
#     'brand:wikipedia': 'en:Valero Energy',
#     'name': 'Valero'}},
#   {'type': 'node',
#    'id': 411908674,
#    'lat': 33.8029936,
#    'lon': -116.9725849,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 411910131,
#    'lat': 33.7478896,
#    'lon': -117.0071117,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Exxon',
#     'brand:wikidata': 'Q4781944',
#     'brand:wikipedia': 'en:Exxon',
#     'name': 'Exxon'}},
#   {'type': 'node',
#    'id': 411910582,
#    'lat': 33.7477511,
#    'lon': -116.977713,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 416184593,
#    'lat': 37.2942537,
#    'lon': -121.9761895,
#    'tags': {'addr:street': 'West Hamilton Avenue',
#     'amenity': 'fuel',
#     'name': 'Beacon',
#     'name:en': '7-Eleven'}},
#   {'type': 'node',
#    'id': 416184595,
#    'lat': 37.2945483,
#    'lon': -121.9657264,
#    'tags': {'amenity': 'fuel', 'name': 'USA Gasoline'}},
#   {'type': 'node',
#    'id': 416337763,
#    'lat': 37.8396119,
#    'lon': -122.2897069,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 416587981,
#    'lat': 37.6313191,
#    'lon': -122.0892764,
#    'tags': {'amenity': 'fuel', 'name': '76'}},
#   {'type': 'node',
#    'id': 416798608,
#    'lat': 37.9115425,
#    'lon': -122.3084439,
#    'tags': {'addr:city': 'El Cerrito',
#     'addr:housenumber': '10602',
#     'addr:street': 'San Pablo Avenue',
#     'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 416809989,
#    'lat': 37.9256737,
#    'lon': -122.3190269,
#    'tags': {'addr:city': 'El Cerrito',
#     'addr:housenumber': '11615',
#     'addr:street': 'San Pablo Avenue',
#     'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 416810302,
#    'lat': 37.9262491,
#    'lon': -122.3193873,
#    'tags': {'addr:city': 'El Cerrito',
#     'addr:housenumber': '11687',
#     'addr:street': 'San Pablo Avenue',
#     'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 418815439,
#    'lat': 37.2374172,
#    'lon': -121.8033083,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 418816687,
#    'lat': 37.2366382,
#    'lon': -121.8033942,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'name': '76'}},
#   {'type': 'node',
#    'id': 419422400,
#    'lat': 36.6040599,
#    'lon': -121.8616305,
#    'tags': {'amenity': 'fuel', 'name': 'USA Gasoline'}},
#   {'type': 'node',
#    'id': 419438222,
#    'lat': 36.7602868,
#    'lon': -121.7501547,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 423210933,
#    'lat': 38.5401828,
#    'lon': -121.7317359,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 423211748,
#    'lat': 38.5408685,
#    'lon': -121.7380166,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 426234118,
#    'lat': 37.7809712,
#    'lon': -122.458522,
#    'tags': {'amenity': 'fuel',
#     'bin': 'yes',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'capacity': '12',
#     'name': 'Chevron',
#     'source': 'survey'}},
#   {'type': 'node',
#    'id': 426266796,
#    'lat': 37.7806252,
#    'lon': -122.467663,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'capacity': '6',
#     'name': 'Shell',
#     'source': 'survey'}},
#   {'type': 'node',
#    'id': 428835601,
#    'lat': 36.9863649,
#    'lon': -122.0317856,
#    'tags': {'amenity': 'fuel',
#     'name': 'Devco Oil',
#     'note': 'No retail gasoline pumps'}},
#   {'type': 'node',
#    'id': 431405445,
#    'lat': 36.9851604,
#    'lon': -121.9895087,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 431405446,
#    'lat': 36.9792673,
#    'lon': -121.9912244,
#    'tags': {'amenity': 'fuel', 'name': 'Z Ma Self Service Gasoline'}},
#   {'type': 'node',
#    'id': 431405447,
#    'lat': 36.9849926,
#    'lon': -121.990012,
#    'tags': {'amenity': 'fuel', 'name': 'USA'}},
#   {'type': 'node',
#    'id': 434096138,
#    'lat': 37.7130588,
#    'lon': -121.7237447,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 434101040,
#    'lat': 37.711389,
#    'lon': -121.7251667,
#    'tags': {'amenity': 'fuel', 'name': 'Gas & Shop'}},
#   {'type': 'node',
#    'id': 434125914,
#    'lat': 37.7174032,
#    'lon': -121.7237294,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 435049639,
#    'lat': 37.8753686,
#    'lon': -122.2944486,
#    'tags': {'amenity': 'fuel', 'name': 'SP'}},
#   {'type': 'node',
#    'id': 435049785,
#    'lat': 37.8682313,
#    'lon': -122.2951245,
#    'tags': {'amenity': 'fuel', 'name': 'EconoGas'}},
#   {'type': 'node',
#    'id': 435198298,
#    'lat': 37.5958635,
#    'lon': -122.5033077,
#    'tags': {'amenity': 'fuel', 'brand': 'Valero'}},
#   {'type': 'node',
#    'id': 435869047,
#    'lat': 37.6139846,
#    'lon': -122.4864181,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 436628327,
#    'lat': 37.4239446,
#    'lon': -122.1958617,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 436765521,
#    'lat': 37.6045821,
#    'lon': -122.3792687,
#    'tags': {'amenity': 'fuel',
#     'fuel:cng': 'yes',
#     'note': 'Natural gas for vehicles. No Gasoline/Petrol or Diesel.',
#     'operator': 'Trillium CNG'}},
#   {'type': 'node',
#    'id': 437515737,
#    'lat': 37.6597649,
#    'lon': -122.4775503,
#    'tags': {'amenity': 'fuel',
#     'brand': '7-Eleven',
#     'brand:wikidata': 'Q259340',
#     'brand:wikipedia': 'en:7-Eleven',
#     'name': '7-Eleven'}},
#   {'type': 'node',
#    'id': 438118918,
#    'lat': 38.5603759,
#    'lon': -121.7590362,
#    'tags': {'amenity': 'fuel', 'brand': 'Chevron', 'shop': 'yes'}},
#   {'type': 'node',
#    'id': 438355616,
#    'lat': 38.4094884,
#    'lon': -121.4056348,
#    'tags': {'amenity': 'fuel', 'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 439172633,
#    'lat': 38.2342168,
#    'lon': -122.6453578,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 440319884,
#    'lat': 36.7919869,
#    'lon': -121.6665263,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 440320253,
#    'lat': 36.7914645,
#    'lon': -121.6684403,
#    'tags': {'amenity': 'fuel', 'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 440415472,
#    'lat': 36.9048143,
#    'lon': -121.7499189,
#    'tags': {'amenity': 'fuel', 'name': 'Golden Gate Gasoline'}},
#   {'type': 'node',
#    'id': 440436834,
#    'lat': 37.0427054,
#    'lon': -122.025463,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell',
#     'opening_hours': 'Mo-Su 00:00-24:00'}},
#   {'type': 'node',
#    'id': 440437811,
#    'lat': 37.0430802,
#    'lon': -122.0246677,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell',
# ...
#   {'type': 'node',
#    'id': 1339197291,
#    'lat': 34.0656792,
#    'lon': -117.3132257,
#    'tags': {'amenity': 'fuel',
#     'brand': '7-Eleven',
#     'fuel:diesel': 'yes',
#     'shop': 'convenience',
#     'source': 'bing_imagery_0.06m_200706;survey;image',
#     'source_ref': 'AM909_DSCX8112'}},
#   {'type': 'node',
#    'id': 1339197354,
#    'lat': 34.0666316,
#    'lon': -117.3248691,
#    'tags': {'amenity': 'fuel',
#     'automated': 'yes',
#     'brand': 'Mobil',
#     'fuel:diesel': 'no',
#     'self_service': 'yes',
#     'shop': 'convenience',
#     'source': 'bing_imagery_0.25m_201005;survey;image',
#     'source_ref': 'AM909_DSCX8100'}},
#   {'type': 'node',
#    'id': 1339274919,
#    'lat': 36.5974297,
#    'lon': -121.8562536,
#    'tags': {'addr:housenumber': '2301',
#     'addr:postcode': '93940',
#     'amenity': 'fuel',
#     'name': '7-Eleven',
#     'opening_hours': '24/7',
#     'phone': '+18313754180'}},
#   {'type': 'node',
#    'id': 1343105062,
#    'lat': 33.9833054,
#    'lon': -117.340305,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'shop': 'convenience',
#     'source': 'bing_imagery_0.06m_200706;survey;image',
#     'source_ref': 'AM909_DSCX8256'}},
#   {'type': 'node',
#    'id': 1344004932,
#    'lat': 37.0250579,
#    'lon': -121.5782037,
#    'tags': {'amenity': 'fuel', 'name': 'Pacific Pride'}},
#   {'type': 'node',
#    'id': 1347410656,
#    'lat': 37.252994,
#    'lon': -121.0026908,
#    'tags': {'amenity': 'fuel', 'name': 'Quick and Easy'}},
#   {'type': 'node',
#    'id': 1347411571,
#    'lat': 37.2536731,
#    'lon': -120.9978118,
#    'tags': {'amenity': 'fuel', 'name': 'Kwik Serv'}},
#   {'type': 'node',
#    'id': 1349777217,
#    'lat': 33.7147205,
#    'lon': -117.1856604,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Valero',
#     'fuel:diesel': 'yes',
#     'shop': 'convenience',
#     'source': 'bing_imagery_0.25m_201005;survey;image',
#     'source_ref': 'AM909_DSCY0509'}},
#   {'type': 'node',
#    'id': 1350006786,
#    'lat': 34.1448517,
#    'lon': -118.7618748,
#    'tags': {'addr:housenumber': '5051',
#     'addr:street': 'West Kanan Street',
#     'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 1350170307,
#    'lat': 33.7869232,
#    'lon': -117.2158932,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'fuel:diesel': 'yes',
#     'payment:credit_cards': 'surcharge',
#     'shop': 'convenience',
#     'source': 'bing_imagery_0.25m_201005;survey;image',
#     'source_ref': 'AM909_DSCY0533'}},
#   {'type': 'node',
#    'id': 1353395799,
#    'lat': 34.427072,
#    'lon': -117.3842405,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 1353395800,
#    'lat': 34.4271402,
#    'lon': -117.385696,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'name': '76',
#     'name:en': '76'}},
#   {'type': 'node',
#    'id': 1354226249,
#    'lat': 32.9126617,
#    'lon': -117.0796846,
#    'tags': {'amenity': 'fuel', 'name': 'Market at the Ranch'}},
#   {'type': 'node',
#    'id': 1354244842,
#    'lat': 32.9343222,
#    'lon': -117.060555,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 1357318684,
#    'lat': 32.9050395,
#    'lon': -117.1456942,
#    'tags': {'amenity': 'fuel', 'source': 'Bing'}},
#   {'type': 'node',
#    'id': 1357773989,
#    'lat': 34.0335652,
#    'lon': -117.322725,
#    'tags': {'amenity': 'fuel',
#     'atm': 'yes',
#     'brand': 'ARCO',
#     'fuel:diesel': 'yes',
#     'source': 'bing_imagery_0.25m_201005;survey;image',
#     'source_ref': 'AM909_DSCY1133'}},
#   {'type': 'node',
#    'id': 1361656008,
#    'lat': 32.7732201,
#    'lon': -117.0049286,
#    'tags': {'amenity': 'fuel', 'name': 'Circle K'}},
#   {'type': 'node',
#    'id': 1365587647,
#    'lat': 35.8761251,
#    'lon': -121.4458954,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 1367502660,
#    'lat': 33.1788077,
#    'lon': -117.2950462,
#    'tags': {'amenity': 'fuel', 'source': 'Bing'}},
#   {'type': 'node',
#    'id': 1371723266,
#    'lat': 36.8890228,
#    'lon': -121.6435012,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 1373480961,
#    'lat': 37.7188977,
#    'lon': -121.910689,
#    'tags': {'addr:city': 'Dublin',
#     'addr:housenumber': '7100',
#     'addr:postcode': '94568',
#     'addr:state': 'CA',
#     'addr:street': 'Dougherty Road',
#     'amenity': 'fuel',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 1373956086,
#    'lat': 37.3837747,
#    'lon': -121.9497088,
#    'tags': {'addr:housenumber': '3473',
#     'amenity': 'fuel',
#     'name': 'Pacific Pride Commercial Fueling'}},
#   {'type': 'node',
#    'id': 1377294065,
#    'lat': 34.4080881,
#    'lon': -117.3986316,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Flying J',
#     'brand:wikidata': 'Q64130592',
#     'name': 'Flying J',
#     'name:en': 'Flying J'}},
#   {'type': 'node',
#    'id': 1377433725,
#    'lat': 33.9177232,
#    'lon': -117.1564348,
#    'tags': {'amenity': 'fuel',
#     'fuel:diesel': 'no',
#     'name': 'Easter Market',
#     'shop': 'convenience',
#     'source': 'bing_imagery_0.25m_201005;survey;image',
#     'source_ref': 'AM909_DSCY0238'}},
#   {'type': 'node',
#    'id': 1379256765,
#    'lat': 38.8144532,
#    'lon': -120.3743271,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 1379549395,
#    'lat': 33.6411088,
#    'lon': -117.167531,
#    'tags': {'addr:city': 'Murrieta',
#     'addr:housenumber': '33070',
#     'addr:postcode': '92563',
#     'addr:state': 'CA',
#     'addr:street': 'Antelope Road',
#     'amenity': 'fuel',
#     'brand': 'ARCO',
#     'fuel:diesel': 'yes',
#     'name': 'Arco',
#     'shop': 'convenience',
#     'source': 'bing_imagery_0.25m_201005;survey;image',
#     'source_ref': 'AM909_DSCY1227'}},
#   {'type': 'node',
#    'id': 1379744306,
#    'lat': 38.8105324,
#    'lon': -121.2838262,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'name': 'Chevron',
#     'source': 'survey;NAIP'}},
#   {'type': 'node',
#    'id': 1381117922,
#    'lat': 34.4707246,
#    'lon': -117.3639839,
#    'tags': {'amenity': 'fuel', 'name': 'Unocal'}},
#   {'type': 'node',
#    'id': 1381429800,
#    'lat': 34.3834168,
#    'lon': -117.3720679,
#    'tags': {'amenity': 'fuel', 'brand': 'Mobil'}},
#   {'type': 'node',
#    'id': 1382815659,
#    'lat': 34.9527097,
#    'lon': -120.4161025,
#    'tags': {'amenity': 'fuel', 'brand': 'Shell', 'name': 'Main Street Shell'}},
#   {'type': 'node',
#    'id': 1382816947,
#    'lat': 34.9527075,
#    'lon': -120.4184989,
#    'tags': {'amenity': 'fuel', 'brand': 'Mobil', 'name': 'Main Street Mobil'}},
#   {'type': 'node',
#    'id': 1385323099,
#    'lat': 34.0642903,
#    'lon': -117.1822938,
#    'tags': {'addr:city': 'Redlands',
#     'addr:housenumber': '902',
#     'addr:street': 'Orange Street',
#     'alt_name': 'USA Gasoline #63346',
#     'amenity': 'fuel',
#     'brand': 'USA Gasoline',
#     'brand:wikidata': 'Q17126373',
#     'brand:wikipedia': 'en:USA Gasoline',
#     'name': 'USA Gasoline'}},
#   {'type': 'node',
#    'id': 1385835072,
#    'lat': 38.7954197,
#    'lon': -121.2648503,
#    'tags': {'addr:housenumber': '6001',
#     'amenity': 'fuel',
#     'name': '7-Eleven'}},
#   {'type': 'node',
#    'id': 1387089728,
#    'lat': 32.7511327,
#    'lon': -117.2418789,
#    'tags': {'amenity': 'fuel', 'source': 'Bing'}},
#   {'type': 'node',
#    'id': 1387190560,
#    'lat': 38.8062335,
#    'lon': -121.2049253,
#    'tags': {'amenity': 'fuel', 'brand': '7 Eleven'}},
#   {'type': 'node',
#    'id': 1387190561,
#    'lat': 38.8068715,
#    'lon': -121.2048492,
#    'tags': {'amenity': 'fuel', 'brand': 'Chevron'}},
#   {'type': 'node',
#    'id': 1387552304,
#    'lat': 36.779276,
#    'lon': -119.7456077,
#    'tags': {'amenity': 'fuel', 'name': 'Valero'}},
#   {'type': 'node',
#    'id': 1388013977,
#    'lat': 34.5364011,
#    'lon': -117.2934154,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 1389876153,
#    'lat': 33.863017,
#    'lon': -117.7865021,
#    'tags': {'amenity': 'fuel'}},
#   {'type': 'node',
#    'id': 1393111962,
#    'lat': 33.9104241,
#    'lon': -117.881428,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Mobil',
#     'brand:wikidata': 'Q3088656',
#     'brand:wikipedia': 'en:Mobil',
#     'name': 'Mobil'}},
#   {'type': 'node',
#    'id': 1393111968,
#    'lat': 33.9105421,
#    'lon': -117.8805483,
#    'tags': {'addr:city': 'Fullerton',
#     'addr:housenumber': '2840',
#     'addr:postcode': '92835',
#     'addr:street': 'Imperial Highway',
#     'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 1396695226,
#    'lat': 33.9137629,
#    'lon': -117.8938485,
#    'tags': {'addr:city': 'Brea',
#     'addr:housenumber': '700',
#     'addr:postcode': '92821',
#     'addr:state': 'CA',
#     'addr:street': 'Imperial Highway',
#     'amenity': 'fuel',
#     'name': 'Chevron',
#     'opening_hours': '24/7'}},
#   {'type': 'node',
#    'id': 1404085519,
#    'lat': 33.0702053,
#    'lon': -117.0706452,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell',
#     'source': 'local knowledge'}},
#   {'type': 'node',
#    'id': 1404991858,
#    'lat': 34.0575136,
#    'lon': -117.1800394,
#    'tags': {'addr:city': 'Redlands',
#     'addr:housenumber': '201',
#     'addr:street': 'East Redlands Boulevard',
#     'amenity': 'fuel',
#     'name': 'Union 76'}},
#   {'type': 'node',
#    'id': 1405147686,
#    'lat': 39.5239026,
#    'lon': -122.2117662,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'ele': '43',
#     'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 1406278760,
#    'lat': 37.2799026,
#    'lon': -121.8230757,
#    'tags': {'amenity': 'fuel', 'name': 'Sunrise 7'}},
#   {'type': 'node',
#    'id': 1407504588,
#    'lat': 33.8825792,
#    'lon': -117.3664149,
#    'tags': {'addr:city': 'Riverside',
#     'addr:housenumber': '16970',
#     'addr:postcode': '92504',
#     'addr:state': 'CA',
#     'addr:street': 'Van Buren Boulevard',
#     'amenity': 'fuel',
#     'brand': '7-Eleven',
#     'brand:wikidata': 'Q259340',
#     'brand:wikipedia': 'en:7-Eleven',
#     'name': '7-Eleven',
#     'opening_hours': '24/7',
#     'shop': 'convenience',
#     'source': 'bing_imagery_0.25m_201005;survey;image',
#     'source_ref': 'AM909_DSCX9227'}},
#   {'type': 'node',
#    'id': 1410244616,
#    'lat': 37.886481,
#    'lon': -122.297488,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'name': 'Arco'}},
#   {'type': 'node',
#    'id': 1410760268,
#    'lat': 37.887031,
#    'lon': -122.297626,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'name': 'Shell'}},
#   {'type': 'node',
#    'id': 1412694845,
#    'lat': 33.9348429,
#    'lon': -117.4536703,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Arco',
#     'brand:wikidata': 'Q304769',
#     'brand:wikipedia': 'en:ARCO',
#     'fuel:diesel': 'no',
#     'name': 'Arco',
#     'source': 'bing_imagery_0.06m_200706;survey;image',
#     'source_ref': 'AM909_DSCX9295'}},
#   {'type': 'node',
#    'id': 1412694859,
#    'lat': 33.9430818,
#    'lon': -117.4544529,
#    'tags': {'amenity': 'fuel',
#     'brand': '76',
#     'brand:wikidata': 'Q1658320',
#     'brand:wikipedia': 'en:76 (gas station)',
#     'fuel:diesel': 'yes',
#     'name': '76',
#     'source': 'bing_imagery_0.06m_200706;survey;image',
#     'source_ref': 'AM909_DSCX9303'}},
#   {'type': 'node',
#    'id': 1416855000,
#    'lat': 37.5519163,
#    'lon': -122.3048361,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Exxon',
#     'brand:wikidata': 'Q4781944',
#     'brand:wikipedia': 'en:Exxon',
#     'name': 'Exxon'}},
#   {'type': 'node',
#    'id': 1417389355,
#    'lat': 37.674391,
#    'lon': -121.0122608,
#    'tags': {'amenity': 'fuel', 'name': 'ampm'}},
#   {'type': 'node',
#    'id': 1417428307,
#    'lat': 37.7382281,
#    'lon': -120.9387566,
#    'tags': {'addr:city': 'Riverbank',
#     'addr:housenumber': '3103',
#     'addr:postcode': '95367',
#     'addr:state': 'CA',
#     'addr:street': 'Atchison Street',
#     'amenity': 'fuel',
#     'brand': 'Shell',
#     'brand:wikidata': 'Q154950',
#     'brand:wikipedia': 'en:Royal Dutch Shell',
#     'fuel:diesel': 'yes',
#     'fuel:midgrade': 'yes',
#     'fuel:premium': 'yes',
#     'fuel:regular': 'yes',
#     'name': 'Shell',
#     'opening_hours': '24/7',
#     'phone': '(209) 869-3030',
#     'self_service': 'yes',
#     'website': 'https://find.shell.com/'}},
#   {'type': 'node',
#    'id': 1417429156,
#    'lat': 37.7378942,
#    'lon': -120.9315283,
#    'tags': {'amenity': 'fuel', 'name': '76'}},
#   {'type': 'node',
#    'id': 1417436332,
#    'lat': 37.7590171,
#    'lon': -120.864949,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Circle K',
#     'brand:wikidata': 'Q3268010',
#     'brand:wikipedia': 'en:Circle K',
#     'name': 'Circle K'}},
#   {'type': 'node',
#    'id': 1417436584,
#    'lat': 37.7610559,
#    'lon': -120.8601354,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Valero',
#     'brand:wikidata': 'Q1283291',
#     'brand:wikipedia': 'en:Valero Energy',
#     'name': 'Valero'}},
#   {'type': 'node',
#    'id': 1419490176,
#    'lat': 37.763112,
#    'lon': -120.8558597,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Chevron',
#     'brand:wikidata': 'Q319642',
#     'brand:wikipedia': 'en:Chevron Corporation',
#     'ele': '55',
#     'name': 'Chevron',
#     'shop': 'yes',
#     'source': 'collected by Volker Bartheld, converted and imported by malenki'}},
#   {'type': 'node',
#    'id': 1419490290,
#    'lat': 37.7616437,
#    'lon': -120.8589635,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Valero',
#     'brand:wikidata': 'Q1283291',
#     'brand:wikipedia': 'en:Valero Energy',
#     'name': 'Valero'}},
#   {'type': 'node',
#    'id': 1419493315,
#    'lat': 37.7406442,
#    'lon': -120.9190089,
#    'tags': {'amenity': 'fuel', 'name': 'U Gas'}},
#   {'type': 'node',
#    'id': 1419591305,
#    'lat': 37.5611407,
#    'lon': -121.1773966,
#    'tags': {'amenity': 'fuel', 'name': 'One Stop'}},
#   {'type': 'node',
#    'id': 1419615738,
#    'lat': 37.470314,
#    'lon': -121.1278867,
#    'tags': {'amenity': 'fuel', 'name': 'Kwik Serve'}},
#   {'type': 'node',
#    'id': 1424275319,
#    'lat': 33.9607194,
#    'lon': -118.2822153,
#    'tags': {'amenity': 'fuel', 'name': '76', 'source': 'survey'}},
#   {'type': 'node',
#    'id': 1424377668,
#    'lat': 33.9598273,
#    'lon': -118.2698663,
#    'tags': {'amenity': 'fuel', 'name': 'Chevron', 'source': 'survey'}},
#   {'type': 'node',
#    'id': 1424377674,
#    'lat': 33.9603813,
#    'lon': -118.2699173,
#    'tags': {'amenity': 'fuel', 'name': 'Valero', 'source': 'survey'}},
#   {'type': 'node',
#    'id': 1432668402,
#    'lat': 37.4901455,
#    'lon': -121.9477192,
#    'tags': {'amenity': 'fuel', 'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 1435985367,
#    'lat': 32.6820977,
#    'lon': -117.0738961,
#    'tags': {'amenity': 'fuel', 'source': 'Bing'}},
#   {'type': 'node',
#    'id': 1436163066,
#    'lat': 32.9071879,
#    'lon': -117.1716808,
#    'tags': {'amenity': 'fuel', 'brand': 'Chevron', 'name': 'Chevron'}},
#   {'type': 'node',
#    'id': 1438451170,
#    'lat': 38.3291133,
#    'lon': -123.0437694,
#    'tags': {'amenity': 'fuel', 'name': '76'}},
#   {'type': 'node',
#    'id': 1440596919,
#    'lat': 38.3287327,
#    'lon': -122.7079458,
#    'tags': {'amenity': 'fuel',
#     'brand': 'USA Gasoline',
#     'brand:wikidata': 'Q17126373',
#     'brand:wikipedia': 'en:USA Gasoline',
#     'name': 'USA Gasoline'}},
#   {'type': 'node',
#    'id': 1441936580,
#    'lat': 34.0412452,
#    'lon': -118.2378348,
#    'tags': {'amenity': 'fuel',
#     'brand': 'Valero',
#     'brand:wikidata': 'Q1283291',
#     'brand:wikipedia': 'en:Valero Energy',
#     'fuel:diesel': 'yes',
#     'fuel:octane_91': 'yes',
#     'fuel:octane_93': 'yes',
#     'fuel:octane_95': 'yes',
#     'name': 'Valero'}},
#   {'type': 'node',
#    'id': 1445188439,
#    'lat': 33.1113423,
#    'lon': -117.0820088,
#    'tags': {'amenity': 'fuel', 'name': 'Quik Korner', 'shop': 'convenience'}},
#   ...]}

# %%
len(response.json()['elements'])
# Out:
# 2927

# %%
response.json()['elements'][10]['tags']['name']
# Out:
# 'Car Service'

# %% [markdown]
# # Create columns:
# - Name
# - Latitude
# - Longitude

# %%
names = []
for x in range(len(response.json()['elements'])):
    if 'name' in response.json()['elements'][x]['tags']:
        names.append(response.json()['elements'][x]['tags']['name'])
    else:
        names.append(None)
names
# Out:
# ['Circle K & Minimart',
#  None,
#  None,
#  'Arco',
#  'Valley Oil',
#  None,
#  'Arco',
#  'Arco',
#  'Shell',
#  '76',
#  'Car Service',
#  'Chevron',
#  'Mobil',
#  'Fuel 24:7',
#  None,
#  'Chevron',
#  'Chevron',
#  None,
#  'Valero',
#  'Chevron',
#  None,
#  None,
#  None,
#  'Valero',
#  '76',
#  'Shell',
#  None,
#  'Shell',
#  'Chevron',
#  'World',
#  'Shell',
#  'Mobil',
#  None,
#  'Clairemont Auto Care',
#  None,
#  None,
#  'Chevron',
#  'Chevron Mission Car Wash',
#  'Arco',
#  'Patriot',
#  'Arco',
#  'Arco',
#  'Shell',
#  'Shell',
#  'Touchless Gasoline',
#  'Arco',
#  'Chevron',
#  'Chevron',
#  None,
#  'Shell',
#  None,
#  'Chevron',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Costco Gasoline',
#  None,
#  'Arco',
#  'Arco',
#  '76',
#  'Cal Gas',
#  'Arco',
#  None,
#  'Chevron',
#  'Shell',
#  'Rotten Robbie #31',
#  'Chevron',
#  'Mobil',
#  None,
#  'Chevron',
#  '7-Eleven',
#  'Chevron',
#  'Chevron',
#  None,
#  None,
#  '76',
#  'Valero',
#  None,
#  'Chevron',
#  'Chevron',
#  'Shell',
#  'VP',
#  "Jesse's",
#  'Golden Eagle',
#  'Quest Mart',
#  'Shell',
#  'Chevron',
#  'Chevron',
#  'Mobil',
#  '76',
#  'Arco',
#  '76',
#  '76 Gas Station',
#  None,
#  '76',
#  'Valero',
#  'Shell',
#  None,
#  'Golden Gate Petroleum',
#  None,
#  None,
#  'Chevron',
#  None,
#  None,
#  None,
#  'Shell',
#  "Ranier's Service Station",
#  'Arco',
#  '76',
#  'Mobil',
#  '76',
#  '76',
#  'R&R',
#  None,
#  'Shell',
#  'Shell',
#  'Chevron',
#  'Mission 76',
#  'USA Gasoline',
#  'Chevron',
#  'Circle K',
#  '7 - Eleven',
#  'Shell',
#  'Chevron',
#  'Rotten Robbie',
#  'Nyack Shell',
#  'Shell',
#  'Shell',
#  'Shell',
#  'Valero',
#  'Arco',
#  None,
#  None,
#  None,
#  None,
#  'Chevron',
#  None,
#  'Chevron',
#  'Chevron',
#  'Shell',
#  '76',
#  '7-Eleven',
#  'USA Gasoline',
#  'Shell',
#  None,
#  '76',
#  '76',
#  None,
#  'Shell',
#  'Chevron',
#  'Chevron',
#  '76',
#  None,
#  '#1 Gas',
#  'Shell',
#  'Hilltop',
#  'Valero',
#  'Chevron',
#  None,
#  None,
#  'Quickstop',
#  'Shell',
#  'Shell',
#  None,
#  'Shell',
#  'Rod & Ros',
#  '76',
#  'Arco',
#  '76',
#  "76 (Om's Market)",
#  'Rotten Robbie',
#  'Valero',
#  'Chevron',
#  'Kwick Serve',
#  'Pilot',
#  'Chevron',
#  '76',
#  'Chevron',
#  'Shell Gas Station',
#  'Chevron',
#  None,
#  'Sav On Gasoline',
#  'Valero',
#  'Valero',
#  'Costco Gasoline',
#  '76 Gas',
#  'APCO Gasoline',
#  'Gas & Shop',
#  'Valero',
#  None,
#  'Exxon',
#  None,
#  'Beacon',
#  'USA Gasoline',
#  None,
#  '76',
#  None,
#  None,
#  None,
#  'Chevron',
#  '76',
#  'USA Gasoline',
#  None,
#  'Chevron',
#  'Shell',
#  'Chevron',
#  'Shell',
#  'Devco Oil',
#  'Shell',
#  'Z Ma Self Service Gasoline',
#  'USA',
#  None,
#  'Gas & Shop',
#  None,
#  'SP',
#  'EconoGas',
#  None,
#  'Chevron',
#  'Shell',
#  None,
#  '7-Eleven',
#  None,
#  'Chevron',
#  'Shell',
#  'Arco',
#  'Chevron',
#  'Golden Gate Gasoline',
#  'Shell',
#  'Shell',
#  'Arco',
#  'Shell',
#  None,
#  None,
#  'Chevron',
#  'Shell',
#  '76',
#  '76',
#  None,
#  'Chevron',
#  'Chevron',
#  'Shell',
#  None,
#  None,
#  None,
#  'Mobil',
#  None,
#  'Safeway',
#  'Chevron',
#  'Chevron',
#  '76',
#  'Mega Fuel',
#  'Chevron',
#  'Chevron',
#  'Shell',
#  None,
#  None,
#  'Shell',
#  'Fastrip',
#  'Shell',
#  'Chevron',
#  'Chevron',
#  '76',
#  'Chevron',
#  'Arco',
#  'Arco',
#  None,
#  'AM/PM',
#  'Chevron',
#  '76',
#  'Shell',
#  'Mash Gas and Food',
#  None,
#  None,
#  None,
#  'Shell',
#  None,
#  'Valero',
#  '76',
#  None,
#  None,
#  'Shell',
#  'Alliance',
#  'Arco',
#  'Shell',
#  '76',
#  '76',
#  None,
#  None,
#  None,
#  '76',
#  None,
#  'Scotts Valley Gas & Mart',
#  'Kensington Service Station',
#  'Shell',
#  'Chevron',
#  'Valero',
#  '76',
#  'Shell',
#  'Mobil',
#  'Haven 76 Tire & Service Center',
#  'Haven Mobil',
#  'Shell',
#  'Patriot Gasoline',
#  '76',
#  'Arco',
#  'Shell',
#  None,
#  'Beacon',
#  'Chevron',
#  'AMPM',
#  'Chevron',
#  None,
#  "Brown's Corner Fuel",
#  'Chevron',
#  'Chevron',
#  'Corner Stone',
#  'Chevron',
#  None,
#  'Mobil',
#  'Chevron',
#  None,
#  'Shell',
#  '76',
#  None,
#  None,
#  None,
#  'Quik Stop',
#  'Valero',
#  "Ralph's Gas",
#  'Chevron',
#  'Chevron',
#  None,
#  '76',
#  'Chevron',
#  'Patriot Gasoline',
#  None,
#  None,
#  'Gas 4 Less',
#  'Patriot Gasoline',
#  None,
#  None,
#  None,
#  'Chevron',
#  'Valero',
#  'Chevron',
#  None,
#  None,
#  '7-Eleven',
#  'Chevron',
#  'Texaco',
#  None,
#  None,
#  'Arco',
#  None,
#  'Flyers',
#  'Shell',
#  None,
#  'Mobil',
#  None,
#  'Arco',
#  'Mobil',
#  None,
#  'Chevron',
#  'Arco',
#  None,
#  None,
#  None,
#  'Chevron',
#  '76',
#  'Arco',
#  None,
#  None,
#  'ARCO',
#  'Shell',
#  'Shell',
#  'Chevron',
#  '76',
#  None,
#  None,
#  "Sam's Club",
#  None,
#  'Costco Gasoline',
#  None,
#  None,
#  'Ralphs Gas Station',
#  '76',
#  None,
#  'Chevron',
#  '76 Gas Station',
#  'Shell',
#  'Arco',
#  'Shell',
#  None,
#  'Chevron',
#  None,
#  None,
#  '76',
#  'St. Clair Valero',
#  'Go Gasoline',
#  'Shell',
#  'Mobil',
#  None,
#  'Arco',
#  'Arco',
#  '76',
#  None,
#  'Arco',
#  None,
#  None,
#  'Arco',
#  None,
#  'Shell',
#  'Chevron',
#  'Chevron',
#  None,
#  'Chevron',
#  'USA Gasoline',
#  'Emerald Oil',
#  'Top Fuel',
#  'Chevron',
#  None,
#  None,
#  'USA Gasoline',
#  None,
#  'Shell',
#  'Arco',
#  None,
#  'Costco Gasoline',
#  'Arco',
#  'Revco',
#  'Arco',
#  'Shell',
#  'Arco',
#  None,
#  'Mobil',
#  'Shell',
#  'USA Gasoline',
#  'XCEL',
#  None,
#  'Arco',
#  'Valero',
#  'Shell',
#  '4S Ranch Gas Station and Car Wash',
#  None,
#  '76',
#  'Chevron',
#  None,
#  'Encinitas Chevron',
#  '76',
#  'Sky Fuel',
#  None,
#  'Kwik Serv',
#  'Arco',
#  'Mobil',
#  None,
#  'Speed Stop',
#  'Shell',
#  None,
#  None,
#  'Arco',
#  'Chevron',
#  '76',
#  None,
#  'Shell Gas',
#  '76',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Valero',
#  None,
#  None,
#  None,
#  'Chevron',
#  'Shell',
#  None,
#  None,
#  '7-Eleven',
#  'Mobil',
#  'Shell',
#  None,
#  'USA Gas',
#  None,
#  None,
#  None,
#  None,
#  'Arco; AM/PM',
#  None,
#  'Texas Gasoline',
#  'Alliiance Mini Mart',
#  '76',
#  'Shell',
#  None,
#  'Chevron',
#  None,
#  '76',
#  'Shell',
#  'Chevron',
#  '76 Roseville Station ',
#  '76',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  '7-Eleven',
#  'Chevron',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Arco - Gas Station',
#  'Alameda Fuel',
#  None,
#  'Valero',
#  'Alpine Mobil',
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Chevron',
#  'Fastbreak Express',
#  'Fuel Depot',
#  'Conserv Fuel',
#  None,
#  None,
#  None,
#  'Specialty Solid Waste CNG Station',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'United Oil',
#  None,
#  'Shell',
#  'C&R',
#  'Arco',
#  '76',
#  'Shell',
#  '76',
#  'Chevron',
#  None,
#  'Chevron',
#  None,
#  None,
#  'Chevron',
#  'Superior Car Wash & Detail Center',
#  None,
#  None,
#  'Circle K',
#  None,
#  'Alliance Gas',
#  None,
#  None,
#  'Chevron',
#  None,
#  'Chevron',
#  None,
#  None,
#  None,
#  None,
#  'Shell',
#  'Chevron',
#  'Chevron',
#  None,
#  'Berri Brothers',
#  None,
#  None,
#  'Chevron',
#  None,
#  'Chevron',
#  None,
#  None,
#  'Chevron',
#  'Shell',
#  None,
#  None,
#  'Mobil',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Arco',
#  None,
#  None,
#  None,
#  'Costco Gasoline',
#  'Chevron',
#  'ARCO',
#  None,
#  None,
#  None,
#  'Mobil',
#  'Arco',
#  'Valero',
#  'Chevron',
#  None,
#  'Mobil',
#  None,
#  'AMPM Gas & Minimart',
#  'Econo',
#  'Chevron',
#  'Shell',
#  'Chevron',
#  '76 Union',
#  'Chevron',
#  None,
#  None,
#  'Laguna Hills Car Wash',
#  None,
#  None,
#  None,
#  'Chevron',
#  None,
#  'Shell',
#  None,
#  'Alliance',
#  None,
#  None,
#  None,
#  'Shell',
#  'Mobil',
#  'Quik-Stop',
#  None,
#  None,
#  'USA Gasoline',
#  'Arco',
#  'Chevron',
#  'Shelter Cove General Store Gas',
#  None,
#  'Shell',
#  'Shell',
#  'Chevron',
#  'Arco',
#  None,
#  None,
#  'Arco',
#  'Chevron',
#  'Shell',
#  'Shell',
#  None,
#  '7-Eleven',
#  '76',
#  'Arco',
#  'Chevron',
#  'Shell',
#  'Shell',
#  'Valero',
#  'Arco',
#  'American Gas - Mini Mart',
#  'Baldwin Gas & Food Mart',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Shell',
#  'Valero',
#  None,
#  None,
#  None,
#  None,
#  'Shell',
#  None,
#  None,
#  None,
#  'Chevron',
#  'Quick Stop',
#  None,
#  None,
#  None,
#  'Mobil',
#  '7-Eleven',
#  None,
#  'Chevron',
#  None,
#  'Shell',
#  None,
#  'Chevron',
#  None,
#  'Thrifty Gas Station',
#  None,
#  None,
#  'Mobil',
#  'Pala Gas Station',
#  None,
#  'Costco Gasoline',
#  'Arco',
#  'Rotten Robbie',
#  'Chevron',
#  '76',
#  'ARCO Fuel Station',
#  'Chevron',
#  None,
#  None,
#  'Valero',
#  'Casa de Fruta Chevron',
#  'Mobil',
#  'Chevron',
#  '76',
#  'Chevron',
#  'Chevron',
#  'Texaco',
#  'Arco',
#  None,
#  'Bel-air Aisle 1',
#  None,
#  'Shell',
#  None,
#  'Mobil',
#  None,
#  None,
#  None,
#  'Circle K',
#  'Shell',
#  "Love's",
#  'Mountain Village',
#  'Chevron',
#  None,
#  'Shell',
#  'Chevron',
#  'Costco Gasoline',
#  'Arco',
#  None,
#  None,
#  None,
#  'Shell',
#  'Jawbone Canyon Store',
#  None,
#  None,
#  None,
#  'Shell',
#  "Don's Gas / Market",
#  'Chevron',
#  'Arco',
#  'Valero',
#  'Chevron',
#  'Shell',
#  '76',
#  None,
#  '76',
#  'Chevron',
#  'Shell',
#  '76',
#  None,
#  None,
#  None,
#  None,
#  'Arco',
#  '76',
#  'Chevron',
#  'Mobil',
#  '76',
#  'Shell',
#  'Double AA',
#  'Redmond 76',
#  '76',
#  'Chevron',
#  'Kwik-Serv',
#  'Chevron',
#  'Shell',
#  None,
#  '76',
#  'San Benito Petroleum',
#  None,
#  None,
#  'Chevron',
#  '76',
#  'Chevron',
#  '76',
#  'National Petroleum',
#  'Chevron',
#  'Chevron',
#  'Valero',
#  'USA Gasoline',
#  'USA Gasoline',
#  '76',
#  'Chevron',
#  None,
#  'Shell',
#  'Marina',
#  'Valero',
#  "Steve's",
#  None,
#  None,
#  'Shell',
#  '76',
#  'Chevron',
#  'Valero',
#  '76',
#  '7-Eleven',
#  '76',
#  'Shell',
#  None,
#  'Shell',
#  'Shell',
#  None,
#  'DoubleTime',
#  'AAFES Express',
#  'Shell',
#  None,
#  None,
#  None,
#  None,
#  'Valero',
#  'Arco',
#  '76',
#  None,
#  'Chevron',
#  'Flyers Energy',
#  'Shell',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Chevron',
#  'Old Cambria Wine and Gifts',
#  'Chevron',
#  '7',
#  None,
#  None,
#  'Orcutt 76',
#  None,
#  None,
#  'Pine Cove Gas & Market',
#  None,
#  None,
#  'Chevron',
#  'Valero Corner Store',
#  'Arco',
#  'Arco',
#  'Arco',
#  'Cal Gas',
#  'Home Gas',
#  '76',
#  'Valero',
#  'Chevron',
#  'Chevron',
#  '76',
#  'Flying J',
#  'Silver Gas & Diesel',
#  'Shell',
#  'Mobil',
#  'Arco',
#  '7-Eleven',
#  None,
#  None,
#  '76 Gas Station',
#  'ARCO Gas Station',
#  'Valero',
#  'Shell',
#  'Chevron',
#  'Flyers',
#  'Shell Gas Station',
#  'Shell',
#  'Valero',
#  'Rapid 14',
#  'Arco',
#  None,
#  'Chevron',
#  "Sam's Club",
#  None,
#  'USA Gas',
#  'Sunnyside 76',
#  None,
#  None,
#  None,
#  '76',
#  'Arco',
#  'Chevron',
#  'Oak Knoll Mobil',
#  'Munoz 76',
#  None,
#  'Chevron',
#  'Chevron',
#  '76',
#  'Holly',
#  '76',
#  None,
#  'Chevron',
#  'Shell',
#  None,
#  'ARCO',
#  'Arco',
#  'Shell',
#  None,
#  None,
#  'Shell',
#  'Shell',
#  None,
#  None,
#  'Arco',
#  None,
#  'Shell',
#  'Chevron',
#  'Circle K',
#  'Arco',
#  None,
#  'Arco',
#  'Shell',
#  None,
#  None,
#  'Arco',
#  'Unocal',
#  None,
#  'Chevron',
#  'Valero',
#  None,
#  None,
#  '7-Eleven',
#  None,
#  'Pacific Pride',
#  'Quick and Easy',
#  'Kwik Serv',
#  None,
#  'Chevron',
#  None,
#  'Arco',
#  '76',
#  'Market at the Ranch',
#  None,
#  None,
#  None,
#  'Circle K',
#  None,
#  None,
#  None,
#  'Chevron',
#  'Pacific Pride Commercial Fueling',
#  'Flying J',
#  'Easter Market',
#  None,
#  'Arco',
#  'Chevron',
#  'Unocal',
#  None,
#  'Main Street Shell',
#  'Main Street Mobil',
#  'USA Gasoline',
#  '7-Eleven',
#  None,
#  None,
#  None,
#  'Valero',
#  None,
#  None,
#  'Mobil',
#  'Arco',
#  'Chevron',
#  'Shell',
#  'Union 76',
#  'Chevron',
#  'Sunrise 7',
#  '7-Eleven',
#  'Arco',
#  'Shell',
#  'Arco',
#  '76',
#  'Exxon',
#  'ampm',
#  'Shell',
#  '76',
#  'Circle K',
#  'Valero',
#  'Chevron',
#  'Valero',
#  'U Gas',
#  'One Stop',
#  'Kwik Serve',
#  '76',
#  'Chevron',
#  'Valero',
#  'Chevron',
#  None,
#  'Chevron',
#  '76',
#  'USA Gasoline',
#  'Valero',
#  'Quik Korner',
#  ...]

# %%
names.count(None)
# Out:
# 758

# %% [markdown]
# #### There are a lot of gas stations without names. bummer

# %%
latitudes = []
for x in range(len(response.json()['elements'])):
    latitudes.append(response.json()['elements'][x]['lat'])
latitudes
# Out:
# [34.0573651,
#  34.0485747,
#  34.0413876,
#  37.7684682,
#  37.381165,
#  34.1032728,
#  37.4060647,
#  37.6774981,
#  37.6777037,
#  37.8373034,
#  37.8407536,
#  37.8404305,
#  37.8394465,
#  37.8400252,
#  37.7755014,
#  37.8255858,
#  37.8579312,
#  37.84382,
#  37.581745,
#  37.5803881,
#  37.5872485,
#  37.5876457,
#  37.578398,
#  37.5887203,
#  37.2210474,
#  33.7165414,
#  37.8385166,
#  37.3731217,
#  32.8670766,
#  32.8548259,
#  32.8543944,
#  32.8542675,
#  32.8227832,
#  32.8342381,
#  32.8342381,
#  32.8348112,
#  38.5510626,
#  34.0909625,
#  37.6003825,
#  40.0093833,
#  37.551753,
#  34.0635637,
#  34.0655247,
#  34.0646722,
#  37.8684979,
#  38.546829,
#  34.0623716,
#  37.4792248,
#  39.2662359,
#  37.764585,
#  33.8798779,
#  33.831782,
#  33.7423831,
#  33.7467724,
#  37.3382722,
#  33.887245,
#  33.8890904,
#  37.6405002,
#  37.8554553,
#  37.8503278,
#  37.7621609,
#  37.7665265,
#  37.3268208,
#  37.3411416,
#  37.3540568,
#  39.1913805,
